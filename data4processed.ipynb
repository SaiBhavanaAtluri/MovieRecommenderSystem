# %% [markdown]
# ###**Extracting features of 2020 movies from Wikipedia**

# %%
! pip install bs4
# Out:
# Requirement already satisfied: bs4 in c:\users\saibh\onedrive\documents\ml simplilearn\mlproject\venv\lib\site-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\saibh\onedrive\documents\ml simplilearn\mlproject\venv\lib\site-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\saibh\onedrive\documents\ml simplilearn\mlproject\venv\lib\site-packages (from beautifulsoup4->bs4) (2.6)

# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"

source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df = pd.concat([df1, df2, df3, df4], ignore_index=True)
df
# Out:
#              Opening  Opening.1                  Title  \
# 0      J A N U A R Y          3             The Grudge
# 1      J A N U A R Y         10             Underwater
# 2      J A N U A R Y         10            Like a Boss
# 3      J A N U A R Y         10          Three Christs
# 4      J A N U A R Y         10      Inherit the Viper
# ..               ...        ...                    ...
# 271  D E C E M B E R         25       We Can Be Heroes
# 272  D E C E M B E R         25      News of the World
# 273  D E C E M B E R         25  One Night in Miami...
# 274  D E C E M B E R         25  Promising Young Woman
# 275  D E C E M B E R         30      Pieces of a Woman
#
#                                     Production company  \
# 0    Screen Gems / Stage 6 Films / Ghost House Pict...
# 1    20th Century Fox / TSG Entertainment / Chernin...
# 2                   Paramount Pictures / Artists First
# 3                                            IFC Films
# 4    Lionsgate / Barry Films / Tycor International ...
# ..                                                 ...
# 271  Netflix / Troublemaker Studios / Double R Prod...
# 272  Universal Pictures / Playtone / Perfect World ...
# 273                                     Amazon Studios
# 274          Focus Features / FilmNation Entertainment
# 275                             Netflix / Bron Studios
#
#                                          Cast and crew  \
# 0    Nicolas Pesce (director/screenplay); Andrea Ri...
# 1    William Eubank (director); Brian Duffield, Ada...
# 2    Miguel Arteta (director); Sam Pitman, Adam Col...
# 3    Jon Avnet (director/screenplay); Eric Nazarian...
# 4    Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                                                 ...
# 271  Robert Rodriguez (director/screenplay); Priyan...
# 272  Paul Greengrass (director/screenplay); Luke Da...
# 273  Regina King (director); Kemp Powers (screenpla...
# 274  Emerald Fennell (director/screenplay); Carey M...
# 275  Kornél Mundruczó (director); Kata Wéber (scree...
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  NaN
# 4                                                  [5]
# ..                                                 ...
# 271                                                NaN
# 272                                                NaN
# 273                                                NaN
# 274                                                NaN
# 275                                                NaN
#
#       Ref.
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 271  [244]
# 272  [245]
# 273  [246]
# 274  [247]
# 275  [248]
#
# [276 rows x 7 columns]

# %%
df_2020 = df[['Title','Cast and crew']]

# %%
df_2020
# Out:
#                      Title                                      Cast and crew
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 271       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 272      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 273  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 274  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 275      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
# [276 rows x 2 columns]

# %%
! pip install tmdbv3api
# Out:
# Requirement already satisfied: tmdbv3api in c:\users\saibh\onedrive\documents\ml simplilearn\mlproject\venv\lib\site-packages (1.9.0)
# Requirement already satisfied: requests in c:\users\saibh\onedrive\documents\ml simplilearn\mlproject\venv\lib\site-packages (from tmdbv3api) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\saibh\onedrive\documents\ml simplilearn\mlproject\venv\lib\site-packages (from requests->tmdbv3api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\saibh\onedrive\documents\ml simplilearn\mlproject\venv\lib\site-packages (from requests->tmdbv3api) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\saibh\onedrive\documents\ml simplilearn\mlproject\venv\lib\site-packages (from requests->tmdbv3api) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\saibh\onedrive\documents\ml simplilearn\mlproject\venv\lib\site-packages (from requests->tmdbv3api) (2024.7.4)

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '0bd3aa653cc7a7d60e58b256d12adf1b'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      print(data_json)
      if data_json['genres']:
          genre_str = " "
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return " ".join(genres)
      else:
          return np.NaN

# %%
df_2020.columns
# Out:
# Index(['Title', 'Cast and crew'], dtype='object')

# %%
#GPT code
from tmdbv3api import Movie
import requests
import numpy as np

tmdb_movie = Movie()

def get_genre(x):
    try:
        # Search for the movie
        result = tmdb_movie.search(x)
        if not result:
            return np.NaN
        
        # Get the movie ID and fetch details
        movie_id = result[0].id
        response = requests.get(f'https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb.api_key}')
        data_json = response.json()

        # Extract genres if available
        if 'genres' in data_json and data_json['genres']:
            genres = [genre['name'] for genre in data_json['genres']]
            return " ".join(genres)
        else:
            return np.NaN
    except Exception as e:
        print(f"Error processing {x}: {e}")
        return np.NaN

# Apply the get_genre function to the movie titles
df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))
# Out:
# Error processing No films had been released on this date as resulting the closure of theaters caused by the COVID-19 pandemic: getattr(): attribute name must be string
# Error processing The SpongeBob Movie: Sponge on the Run (Canadian theatrical release): getattr(): attribute name must be string
# C:\Users\saibh\AppData\Local\Temp\ipykernel_7228\3590949959.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))
# Out:
# Error processing No films had been released on this date as resulting the closure of theaters caused by the COVID-19 pandemic: getattr(): attribute name must be string
# Error processing The SpongeBob Movie: Sponge on the Run (Canadian theatrical release): getattr(): attribute name must be string
# C:\Users\saibh\AppData\Local\Temp\ipykernel_7228\2588226551.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 271       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 272      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 273  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 274  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 275      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                                       genres
# 0                             Horror Mystery
# 1    Horror Science Fiction Action Adventure
# 2                                     Comedy
# 3                                      Drama
# 4                       Crime Thriller Drama
# ..                                       ...
# 271             Family Action Fantasy Comedy
# 272                  Drama Western Adventure
# 273                                    Drama
# 274                     Thriller Crime Drama
# 275                                    Drama
#
# [276 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\saibh\AppData\Local\Temp\ipykernel_7228\3848435694.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# C:\Users\saibh\AppData\Local\Temp\ipykernel_7228\1815024756.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))
# Out:
# C:\Users\saibh\AppData\Local\Temp\ipykernel_7228\3667490226.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 271       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 272      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 273  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 274  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 275      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                                       genres     director_name  \
# 0                             Horror Mystery     Nicolas Pesce
# 1    Horror Science Fiction Action Adventure    William Eubank
# 2                                     Comedy     Miguel Arteta
# 3                                      Drama         Jon Avnet
# 4                       Crime Thriller Drama    Anthony Jerjen
# ..                                       ...               ...
# 271             Family Action Fantasy Comedy  Robert Rodriguez
# 272                  Drama Western Adventure   Paul Greengrass
# 273                                    Drama       Regina King
# 274                     Thriller Crime Drama   Emerald Fennell
# 275                                    Drama  Kornél Mundruczó
#
#               actor_1_name       actor_2_name     actor_3_name
# 0       Andrea Riseborough      Demián Bichir         John Cho
# 1          Kristen Stewart     Vincent Cassel  Jessica Henwick
# 2          Tiffany Haddish         Rose Byrne      Salma Hayek
# 3             Richard Gere     Peter Dinklage   Walton Goggins
# 4            Josh Hartnett  Margarita Levieva   Chandler Riggs
# ..                     ...                ...              ...
# 271  Priyanka Chopra Jonas       Pedro Pascal    YaYa Gosselin
# 272              Tom Hanks      Helena Zengel              NaN
# 273      Kingsley Ben-Adir          Eli Goree      Aldis Hodge
# 274         Carey Mulligan         Bo Burnham      Alison Brie
# 275          Vanessa Kirby       Shia LaBeouf     Molly Parker
#
# [276 rows x 7 columns]

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})

# %%
df_2020.columns
# Out:
# Index(['movie_title', 'Cast and crew', 'genres', 'director_name',
#        'actor_1_name', 'actor_2_name', 'actor_3_name'],
#       dtype='object')

# %%
new_df20 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 271  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 272   Paul Greengrass              Tom Hanks      Helena Zengel
# 273       Regina King      Kingsley Ben-Adir          Eli Goree
# 274   Emerald Fennell         Carey Mulligan         Bo Burnham
# 275  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name                                   genres  \
# 0           John Cho                           Horror Mystery
# 1    Jessica Henwick  Horror Science Fiction Action Adventure
# 2        Salma Hayek                                   Comedy
# 3     Walton Goggins                                    Drama
# 4     Chandler Riggs                     Crime Thriller Drama
# ..               ...                                      ...
# 271    YaYa Gosselin             Family Action Fantasy Comedy
# 272              NaN                  Drama Western Adventure
# 273      Aldis Hodge                                    Drama
# 274      Alison Brie                     Thriller Crime Drama
# 275     Molly Parker                                    Drama
#
#                movie_title
# 0               The Grudge
# 1               Underwater
# 2              Like a Boss
# 3            Three Christs
# 4        Inherit the Viper
# ..                     ...
# 271       We Can Be Heroes
# 272      News of the World
# 273  One Night in Miami...
# 274  Promising Young Woman
# 275      Pieces of a Woman
#
# [276 rows x 6 columns]

# %%
new_df20['comb'] = new_df20['actor_1_name'] + ' ' + new_df20['actor_2_name'] + ' '+ new_df20['actor_3_name'] + ' '+ new_df20['director_name'] +' ' + new_df20['genres']

# %%
new_df20.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      5
# actor_3_name     28
# genres            2
# movie_title       0
# comb             29
# dtype: int64

# %%
new_df20 = new_df20.dropna(how='any')

# %%
new_df20.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df20['movie_title'] = new_df20['movie_title'].str.lower()
# Out:
# C:\Users\saibh\AppData\Local\Temp\ipykernel_7228\2267385682.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df20['movie_title'] = new_df20['movie_title'].str.lower()

# %%
new_df20
# Out:
#         director_name  ...                                               comb
# 0       Nicolas Pesce  ...  Andrea Riseborough Demián Bichir John Cho Nico...
# 1      William Eubank  ...  Kristen Stewart Vincent Cassel Jessica Henwick...
# 2       Miguel Arteta  ...  Tiffany Haddish Rose Byrne Salma Hayek Miguel ...
# 3           Jon Avnet  ...  Richard Gere Peter Dinklage Walton Goggins Jon...
# 4      Anthony Jerjen  ...  Josh Hartnett Margarita Levieva Chandler Riggs...
# ..                ...  ...                                                ...
# 268       Pete Docter  ...  Jamie Foxx Tina Fey Graham Norton Pete Docter ...
# 269  Robert Rodriguez  ...  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 271       Regina King  ...  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 272   Emerald Fennell  ...  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 273  Kornél Mundruczó  ...  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [246 rows x 7 columns]

# %%
old_df = pd.read_csv('final_data.csv')

# %%
old_df
# Out:
#                director_name       actor_1_name          actor_2_name  \
# 0              James Cameron        CCH Pounder      Joel David Moore
# 1             Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                 Sam Mendes    Christoph Waltz          Rory Kinnear
# 3          Christopher Nolan          Tom Hardy        Christian Bale
# 4             Andrew Stanton       Daryl Sabara       Samantha Morton
# ...                      ...                ...                   ...
# 5735  Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 5736            Greta Gerwig      Saoirse Ronan           Emma Watson
# 5737              Sam Mendes      George MacKay  Dean-Charles Chapman
# 5738   Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5739         Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#               actor_3_name                                    genres  \
# 0                Wes Studi           Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport                  Action Adventure Fantasy
# 2         Stephanie Sigman                 Action Adventure Thriller
# 3     Joseph Gordon-Levitt                           Action Thriller
# 4             Polly Walker                   Action Adventure Sci-Fi
# ...                    ...                                       ...
# 5735         Rashida Jones  Animation Action Adventure Comedy Family
# 5736         Florence Pugh                     Drama Romance History
# 5737           Mark Strong                  War Action Drama History
# 5738           Brie Larson                       Drama Crime History
# 5739           Aldis Hodge                                     Drama
#
#                                    movie_title  \
# 0                                       avatar
# 1     pirates of the caribbean: at world's end
# 2                                      spectre
# 3                        the dark knight rises
# 4                                  john carter
# ...                                        ...
# 5735                         spies in disguise
# 5736                              little women
# 5737                                      1917
# 5738                                just mercy
# 5739                                  clemency
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Daryl Sabara Samantha Morton Polly Walker Andr...
# ...                                                 ...
# 5735  Will Smith Tom Holland Rashida Jones Nick Brun...
# 5736  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5737  George MacKay Dean-Charles Chapman Mark Strong...
# 5738  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5739  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [5740 rows x 7 columns]

# %%
final_df = pd.concat([old_df,new_df20],ignore_index=True)

# %%
final_df
# Out:
#           director_name           actor_1_name      actor_2_name  \
# 0         James Cameron            CCH Pounder  Joel David Moore
# 1        Gore Verbinski            Johnny Depp     Orlando Bloom
# 2            Sam Mendes        Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan              Tom Hardy    Christian Bale
# 4        Andrew Stanton           Daryl Sabara   Samantha Morton
# ...                 ...                    ...               ...
# 5982        Pete Docter             Jamie Foxx          Tina Fey
# 5983   Robert Rodriguez  Priyanka Chopra Jonas      Pedro Pascal
# 5984        Regina King      Kingsley Ben-Adir         Eli Goree
# 5985    Emerald Fennell         Carey Mulligan        Bo Burnham
# 5986   Kornél Mundruczó          Vanessa Kirby      Shia LaBeouf
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4             Polly Walker          Action Adventure Sci-Fi
# ...                    ...                              ...
# 5982         Graham Norton  Animation Family Comedy Fantasy
# 5983         YaYa Gosselin     Family Action Fantasy Comedy
# 5984           Aldis Hodge                            Drama
# 5985           Alison Brie             Thriller Crime Drama
# 5986          Molly Parker                            Drama
#
#                                    movie_title  \
# 0                                       avatar
# 1     pirates of the caribbean: at world's end
# 2                                      spectre
# 3                        the dark knight rises
# 4                                  john carter
# ...                                        ...
# 5982                                      soul
# 5983                          we can be heroes
# 5984                     one night in miami...
# 5985                     promising young woman
# 5986                         pieces of a woman
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Daryl Sabara Samantha Morton Polly Walker Andr...
# ...                                                 ...
# 5982  Jamie Foxx Tina Fey Graham Norton Pete Docter ...
# 5983  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 5984  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 5985  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 5986  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [5987 rows x 7 columns]

# %%
final_df.to_csv('main_data.csv',index=False)
